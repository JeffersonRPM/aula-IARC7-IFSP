# %%
import locale
locale.setlocale(locale.LC_ALL, 'pt_BR.utf8')
import pandas as pd
import plotly as px

# seaborn cria os graficos e o matplotlib exibe os graficos
import seaborn as sns
import matplotlib.pyplot as plt

#sklearn e a biblioteca para trinamento de IA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

#tkinter e a parte do front do programa 
import requests
from tkinter import *
from tkinter import ttk

# %% [markdown]
# # Tratamento de dados e inserção das tabelas

# %% [markdown]
# Lista de bairros apresentados nos dados

# %%
#Lista de todos os bairros apresentados no dataset
lista_bairros = [ ' Vila Independência ',
                ' Dois Córregos ',
                ' Centro ',
                ' Morato ',
                ' Jardim Residencial Javary II ',
                ' Chácara Esperia ', 
                ' Unileste ', 
                ' Bongue ', 
                ' Campestre ', 
                ' Pau Queimado ', 
                ' Água Branca ', 
                ' Jardim Parque Jupiá ', 
                ' Canal Torto ', 
                ' Santa Terezinha ',
                ' Piracicamirim ', 
                ' Itaperu ', 
                ' Nova Piracicaba ', 
                ' Cidade Alta ', 
                ' Monte Alegre ', 
                ' Chácara Nazaré ', 
                ' Batistada ', 
                ' Vila Industrial ', 
                ' Paulicéia ', 
                ' Jardim Elite ', 
                ' Vila Rezende ', 
                ' Jardim Europa ', 
                ' Loteamento Jardim Santa Maria ', 
                ' São Dimas ', 
                ' Pompéia ', 
                ' Ondas ',
                ' Jardim Caxambu ', 
                ' Santa Rita ', 
                ' Glebas Califórnia ', 
                ' Altos do Taquaral ',
                ' Castelinho ', 
                ' Alambari ', 
                ' Cidade Jardim ', 
                ' Nova Suiça ',
                ' Parque Santa Cecília ', 
                ' Nova América ', 
                ' Jardim São Francisco ', 
                ' Areião ', 
                ' Agua Bonita ', 
                ' Parque Conceição II ', 
                ' Centro (Tupi) ', 
                ' Água Seca ', 
                ' Paulista ', 
                ' Parque Taquaral ', 
                ' Clube de Campo ', 
                ' Alto ', 
                ' São Judas ', 
                ' Jardim Nova Suíça ', 
                ' Higienópolis ', 
                ' Santa Rosa ', 
                ' Terras de Piracicaba ', 
                ' Jardim Monumento ', 
                ' Alto da Boa Vista ', 
                ' Condominio Residencial quinta de santa helena ', 
                ' Salto de Pederneiras ', 
                ' Área Rural de Piracicaba ', 
                ' Parque Nossa Senhora das Graças ', 
                ' Jardim Brasília ', 
                ' São Jorge ', 
                ' Vila Monteiro ', 
                ' Monte Rey ', 
                ' Jardim São José ', 
                ' Perdizes ', 
                ' Jardim Santa Silvia ', 
                ' Parque São Matheus ', 
                ' São Vicente II ', 
                ' Parque Santa Terezinha ', 
                ' Vila Sônia ', 
                ' Nova Pompéia ', 
                ' Vale do Sol ', 
                ' Volta Grande ', 
                ' Parque Conceição ', 
                ' Vivendas Bela Vista ', 
                ' Residencial Bertolucci ', 
                ' Tupi ',
                ' Vila Prudente ', 
                ' Jardim Petrópolis ', 
                ' Morumbi ', 
                ' Terra Nova ', 
                ' Prezotto ', 
                ' Jardim Abaeté ', 
                ' Vila Verde ', 
                ' Gran Park Residencial ', 
                ' Loteamento Chácaras Nazareth II ', 
                ' Taquaral ', 
                ' Gran Park ', 
                ' Jardim Flamboyant ', 
                ' Jardim São Luiz ', 
                ' Jardim Residencial Itabera ', 
                ' Jardim Nova Iguaçu ', 
                ' Residencial Nova Água Branca II ', 
                ' Residencial Serra Verde ', 
                ' Vila Nossa Senhora Aparecida ', 
                ' Jaraguá ', 
                ' Jardim Algodoal ', 
                ' Paredão Vermelho ', 
                ' Jardim Astúrias I ', 
                ' Jardim São Vicente Ii ', 
                ' Jardim São Vicente ', 
                ' Jardim Mercedes ', 
                ' Jardim Planalto ', 
                ' Nossa Senhora de Fátima ', 
                ' Parque Orlanda I ', 
                ' Santa Olímpia ', 
                ' Recanto da Água Branca ', 
                ' Santana ', 
                ' Garças ', 
                ' Residencial Alto da Boa Vista ', 
                ' Residencial Altos do Piracicaba ', 
                ' Jardim Santa Isabel ', 
                ' São Vicente I ', 
                ' Convivio Santa Clara ', 
                ' Alto da Pompéia ', 
                ' Jardim Alvorada ', 
                ' Residencial Mont Carlo ', 
                ' Joy One Residence ', 
                ' vila nazareti ', 
                ' Terra Rica ', 
                ' Jardim dos Manacás ', 
                ' Pombeva ', 
                ' Parque Residencial Monte Rey ', 
                ' Jardim Noiva da Colina ', 
                ' Irmãos Camolesi ', 
                ' Jardim Astúrias II ', 
                ' Cecap ', 
                ' Loteamento São Francisco ', 
                ' Jardim Três Marias ', 
                ' Jardim Boa Esperança ', 
                ' Conceição ', 
                ' Residencial Jardins ', 
                ' Reserva Jequitiba ', 
                ' Vila Boyes ', 
                ' Conquista ', 
                ' Residencial Parque Água Branca ', 
                ' Iaa ', 
                ' Parque Chapadão ', 
                ' Campos Do Conde ', 
                ' Jardim Glória ', 
                ' Vila Bessy ', 
                ' Conjunto Habitacional Água Branca ', 
                ' Jardim Bartira ', 
                ' Conjunto Residencial Mário Dedini ', 
                ' Parque Água Branca ', 
                ' Parque Conceição I ', 
                ' Terra Rica III ', 
                ' Mário Dedini ', 
                ' Jardim Monte Castelo ', 
                ' Jardim Esplanada ', 
                ' Sol Nascente II ', 
                ' Jardim Belvedere ', 
                ' Parque das Águas ', 
                ' Jardim Diamante ', 
                ' Algodoal ', 
                ' Jardim Maria Claudia ', 
                ' Jardim Califórnia ', 
                " Pau D'Alhinho ", 
                ' Jardim Residencial Javary III ', 
                ' Terras Altas ', 
                ' Jupia ', 
                ' Santa Teresinha de Piraci ', 
                ' Edificio Espaço Jardins ', 
                ' Torres do Jardim I ', 
                ' Parque Residencial Monte Rey III ', 
                ' Eldorado ', 
                ' Jardim Itapuã ', 
                ' Verde ', 
                ' Residencial Novo Porto ', 
                ' Residencial Portal da Água Branca ', 
                ' Varandas Campestre ', 
                ' Residencial Campos do Conde ', 
                ' Edifício Tarumã ', 
                ' Edificio Colinas de Piracicaba ', 
                ' Vitta Água Branca ', 
                ' Condomínio Santa Tereza ', 
                ' Condomínio Parque Piazza Venezia ', 
                ' Jardim Monte Líbano ', 
                ' Jardim Maria ', 
                ' Tanquinho ', 
                ' Jardim Primavera ', 
                ' Monte Líbano ', 
                ' Jardim Residencial Javary I ', 
                ' Novo Horizonte ', 
                ' Park Monte Rey III ', 
                ' Loteamento Distrito Industrial Uninorte ', 
                ' Areão ', 
                ' Parque São Jorge ', 
                ' Capim Fino ', 
                ' Jardim São Mateus ', 
                ' Jardim Ibirapuera ', 
                ' Jardim São Paulo ', 
                ' São Vicente ', 
                ' São Luiz ', 
                ' Astúrias ', 
                ' Jardim Tatuapé ', 
                ' Humberto Venturini ', 
                ' Vitta Residencial Itapuã ', 
                ' Matão ', 
                ' Jardim Irapuã ', 
                ' Bosque dos Lenheiros ', 
                ' Parque Piazza Fontanella ', 
                ' Parque Residencial Piracicaba ', 
                ' Piazza San Marco ',
                ' Palladio ',
                ' Monet Residencial ',
                ' Jardim Pombeva ',
                ' Residencial Andorinhas ',
                ' Edifício Vermont ',
                ' Jardim São Jorge ',
                ' Spazio Pallazio de Spagna ',
                ' ALEMAES ',
                ' ALPES SUIÇOS ',
                ' ALTOS DO PIRACICABA ', 
                ' ALTOS DO SÃO FRANCISCO ',
                ' ALVORADA ',
                ' ARY COELHO ',
                ' BOA VISTA ',
                ' BOSQUE AGUA BRANCA ',
                ' CENTRO (ÁRTEMIS) ',
                ' CHÁCARA IPÊ ',
                ' CHÁCARAS ÁGUA BRANCA ',
                ' CHACARAS UNIAO ',
                ' CHAPADAO ',
                ' COLINAS DO PIRACICABA (ÁRTEMIS) ',
                ' ESTANCIA LAGO AZUL (ARTEMIS) ',
                ' GLEBAS NATALINAS ',
                ' GUAMIUM ',
                ' IBIRAPUERA ',
                ' IPANEMA ',
                ' JARDIM AMAN ',
                ' JARDIM CASTOR ',
                ' JARDIM DAS FLORES ',
                ' JARDIM DAS OLIVEIRAS ',
                ' JARDIM DOS MANACAS ',
                ' JARDIM GLORIA ',
                 ' JARDIM IPANEMA ',
                 ' JARDIM ITAMARACA ',
                 ' JARDIM MONTE FELIZ ',
                 ' JARDIM NOVA REPUBLICA ', 
                 ' JARDIM SAO PAULO ',
                 ' JARDIM SOL NASCENTE II ',
                 ' JARDIM SONIA ',
                 ' JARDIM TAIGUARA ',
                 ' JARDIM TATUAPE ',
                 ' JARDIM TOKIO ',
                 ' LOTEAMENTO VEM VIVER PIRACICABA I ',
                 ' MONTE FELIZ ',
                 ' NOIVA DA COLINA ',
                 ' NOVA IGUAÇU ',
                 ' ONDINHAS ',
                 ' PACAEMBU ',
                 ' PAINEIRAS ',
                 ' PANORAMA ',
                 ' PARQUE PEORIA (TUPI) ',
                 ' PETROPOLIS ',
                 ' PRIMEIRO DE MAIO ',
                 ' RESERVA DO ENGENHO ',
                 ' RESIDENCIAL SANTO ANTÔNIO ',
                 ' RESIDENCIAL TERRAS DE ÁRTEMIS (ÁRTEMIS) ',
                 ' SANTA CECILIA ',
                 ' SANTA FE ',
                 ' SANTA INES ',
                 ' SANTA ROSA IPÊS ',
                 ' SANTO ANTONIO ',
                 ' SÃO FRANCISCO ',
                 ' SOL NASCENTE ',
                 ' SP 127 KM 42 ',
                 ' TERRAS DE PIRACICABA II ',
                 ' TERRAS DI TREVISO ',
                 ' VILA CRISTINA ',
                 ' VILA FATIMA ',
                 ' VILA PACAEMBU ',
                 ' MINAS NOVAS ',
                 ' JARDIM TAIGUARA I ']

# %% [markdown]
# Lista de tipos de imoveis apresentados nos dados

# %%
#lista de casa, apartamento, terreno ...
lista_cs_ap_tr = ['Prédio Comercial ', 
                'Terreno',
                'Galpão ',
                'Sítio / Fazenda ',
                'Casa Comercial ',
                'Casa ',
                'Apartamento ',
                'Salão ',
                'Terreno ',
                'Chácara ',
                'Sala Comercial ',
                'Edícula ',
                'Kitnet ',
                'Galpão',
                'Prédio Comercial',
                'Salão',
                'Sala Comercial',
                'Casa',
                'Casa Comercial',
                'Apartamento',
                'Área',
                'Chácara',
                'Kitnet' ]

# %% [markdown]
# # Inserção dos datasets e tratamento de dados da IA de venda

# %%
#Lê a tabela de vendas da imobiliaria Juqueira
tabela_venda_juqueira = pd.read_excel("C:/Users/jeffe/Downloads/datasetJuqueiraVenda.xlsx") 

#Lê a tabala de alugueis da imobiliaria Juqueira
tabela_venda_ato = pd.read_excel("C:/Users/jeffe/Downloads/dataset_vendaAto.xlsx")

display(tabela_venda_juqueira) #mostra a tabela de vendas da imobiliaria Juqueira

display(tabela_venda_ato) #mostra a tabela de alugueis da imobiliaria Juqueira
# Out:
#       Unnamed: 0            Imobiliaria        Cidade Estado  \
# 0              0  Imobiliária Junqueira   Piracicaba      SP
# 1              1  Imobiliária Junqueira   Piracicaba      SP
# 2              2  Imobiliária Junqueira   Piracicaba      SP
# 3              3  Imobiliária Junqueira   Piracicaba      SP
# 4              4  Imobiliária Junqueira   Piracicaba      SP
# ...          ...                    ...           ...    ...
# 1633        1633  Imobiliária Junqueira   Piracicaba      SP
# 1634        1634  Imobiliária Junqueira   Piracicaba      SP
# 1635        1635  Imobiliária Junqueira   Piracicaba      SP
# 1636        1636  Imobiliária Junqueira   Piracicaba      SP
# 1637        1637  Imobiliária Junqueira   Piracicaba      SP
#
#                               Bairro     Valor  Lançamento Venda/Aluguel  \
# 0                Vila Independência   15000000         NaN         Venda
# 1                     Dois Córregos   13000000         NaN         Venda
# ...

# %%
#Unifica as tabelas de vendas e alugueis da imobiliaria Juqueira
tabela_dataset_venda = pd.concat([tabela_venda_juqueira, tabela_venda_ato], ignore_index=True) 

#mostra a tabela completa da imobiliaria Juqueira
display(tabela_dataset_venda)
# Out:
#       Unnamed: 0            Imobiliaria        Cidade Estado  \
# 0              0  Imobiliária Junqueira   Piracicaba      SP
# 1              1  Imobiliária Junqueira   Piracicaba      SP
# 2              2  Imobiliária Junqueira   Piracicaba      SP
# 3              3  Imobiliária Junqueira   Piracicaba      SP
# 4              4  Imobiliária Junqueira   Piracicaba      SP
# ...          ...                    ...           ...    ...
# 3271        1633        Imobiliária Ato   Piracicaba      SP
# 3272        1634        Imobiliária Ato   Piracicaba      SP
# 3273        1635        Imobiliária Ato   Piracicaba      SP
# 3274        1636        Imobiliária Ato   Piracicaba      SP
# 3275        1637        Imobiliária Ato   Piracicaba      SP
#
#                               Bairro     Valor  Lançamento Venda/Aluguel  \
# 0                Vila Independência   15000000         NaN         Venda
# 1                     Dois Córregos   13000000         NaN         Venda
# ...

# %%
#da um drop nas colunas: Unnamed: 0, Lançamentos, cidade e estado
tabela_dataset_venda = tabela_dataset_venda.drop(columns=['Unnamed: 0','Lançamento','Cidade','Estado', 'Unnamed: 0.1', 'Unnamed: 0.2', 'Imobiliaria'])

# %%
#deixa toda a coluna de bairro maiuscula 
tabela_dataset_venda['Bairro'] = tabela_dataset_venda['Bairro'].str.upper()
                                        
#troca as letra que faltaram acentuação
tabela_dataset_venda = tabela_dataset_venda.replace(' AGUA BRANCA ', ' ÁGUA BRANCA ').replace(' AGUA SECA ', ' ÁGUA SECA ').replace(' ASTURIAS ', ' ASTÚRIAS ').replace(' CHACARA ESPERIA ', ' CHáCARA ESPERIA ').replace(' CONCEICAO ', ' CONCEIçãO ').replace(' DOIS CORREGOS ', ' DOIS CóRREGOS ').replace(' GLEBAS CALIFORNIA ', ' GLEBAS CALIFóRNIA ').replace(' GRANDE PARQUE RESIDENCIAL ', ' GRAN PARk RESIDENCIAL ').replace(' HIGIENOPOLIS ', ' HIGIENóPOLIS ').replace(' JARAGUA ', ' JARAGUá ').replace(' JARDIM BARTIRA (TUPI) ', ' JARDIM BARTIRA ').replace(' JARDIM BRASILIA ', ' JARDIM BRASíLIA ').replace(' JARDIM CALIFORNIA ', ' JARDIM CALIFóRNIA ').replace(' MARIO DEDINI ', ' MáRIO DEDINI ').replace(' MONTE LIBANO ', ' MONTE LíBANO ').replace(' NOSSA SENHORA DE FATIMA ', ' NOSSA SENHORA DE FáTIMA ').replace(' NOVA AMERICA ', ' NOVA AMéRICA ').replace(' NOVO HORIZINTE ', ' NOVO HORIZoNTE ').replace(' PARQUE CHAPADAO ', ' PARQUE CHAPADãO ').replace(' PARQUE RESIDENCIAL PIRACICABA BALBO ', ' PARQUE RESIDENCIAL PIRACICABA ')
tabela_dataset_venda = tabela_dataset_venda.replace(' PARQUE SAO MATHEUS ', ' PARQUE SãO MATHEUS ').replace(" PAU D`ALHINHO ", " Pau D'Alhinho ").replace(' PAULICEIA ', ' PAULICéIA ').replace(' POMPEIA ', ' POMPéIA ').replace(' POMPEVA ', ' POMbEVA ').replace(' PREZOTO ', ' PREZOTtO ').replace(' SAO DIMAS ', ' SÃO DIMAS ').replace(' SAO FRANCISCO ', ' SãO FRANCISCO ').replace(' SÃO FRANCISCO AVENCAS ', ' SÃO FRANCISCO ').replace(' SAO JORGE ', ' SãO JORGE ').replace(' SAO JUDAS ', ' SãO JUDAS ').replace(' SAO LUIZ ', ' SãO LUIZ ').replace(' TANQUINHO (GUAMIUM) ', ' TANQUINHO ').replace(' VILA INDEPENDENCIA ', ' VILA INDEPENDÊNCIA ').replace(' VILA SONIA ', ' VILA SôNIA ')

#deixa toda a coluna de bairro maiuscula 
tabela_dataset_venda['Bairro'] = tabela_dataset_venda['Bairro'].str.upper()

#muda o nome dos bairros para numeros
for n in range(len(lista_bairros)):
    tabela_dataset_venda = tabela_dataset_venda.replace(lista_bairros[n].upper(), n + 1) 
    
#Muda a venda para 1 
tabela_dataset_venda = tabela_dataset_venda.replace('Venda', 1)

#arrumar oq se repete em cima
tabela_dataset_venda = tabela_dataset_venda.replace('Área', 'Terreno').replace('Prédio Comercial ', 'Prédio Comercial').replace('Terreno ', 'Terreno').replace('Galpão ', 'Galpão').replace('Casa Comercial ', 'Casa Comercial').replace('Casa ', 'Casa').replace('Apartamento ', 'Apartamento').replace('Salão ', 'Salão').replace('Chácara ', 'Chácara').replace('Sala Comercial ', 'Sala Comercial').replace('Kitnet ', 'Kitnet')

#nova lista de casa/apartamento/terreno para numeros
lista_cs_ap_tr_nova_venda = ['Terreno',
                    'Casa',
                    'Apartamento',
                    'Prédio Comercial',
                    'Galpão',
                    'Sítio / Fazenda ',
                    'Casa Comercial',
                    'Salão',
                    'Chácara',
                    'Sala Comercial',
                    'Edícula ',
                    'Kitnet',
                    'Área' ]

#Muda a casa/apartamento/terreno para numeros
for i in range(len(lista_cs_ap_tr_nova_venda)):
    tabela_dataset_venda = tabela_dataset_venda.replace(lista_cs_ap_tr_nova_venda[i], i + 1)

#Usar apenas terreno, casa e apartamento 
tabela_dataset_venda = tabela_dataset_venda[tabela_dataset_venda['Casa/Apartamento/Terreno'] <= 3]  

#tirar todas as linhas de preço que estao vazias
tabela_dataset_venda = tabela_dataset_venda[tabela_dataset_venda['Valor'] > 1]

#tirar todas as linhas que nao tem m²
tabela_dataset_venda = tabela_dataset_venda[tabela_dataset_venda['Metros²'] >= 10]

#Adiociona zero em todos os valores que estao vazio 
tabela_dataset_venda = tabela_dataset_venda.fillna(0)

# %%
display(tabela_dataset_venda)

#Mostra as informações das colunas para saber se ha alguma string nela
print(tabela_dataset_venda.info())
# Out:
#       Bairro     Valor  Venda/Aluguel  Casa/Apartamento/Terreno  Quartos  \
# 1          2  13000000              1                         1      0.0
# 2          3  13000000              1                         1      0.0
# 3          4  12800000              1                         1      0.0
# 4          5  10000000              1                         1      0.0
# 6          6   8000000              1                         1      0.0
# ...      ...       ...            ...                       ...      ...
# 3271      34    100000              1                         1      0.0
# 3272     186     95000              1                         1      0.0
# 3273     187     85000              1                         1      0.0
# 3274       3     85000              1                         3      1.0
# 3275     187     85000              1                         1      0.0
#
#       Suites  Vagas Estacionamento    Metros²
# ...

# %%
#salva a tabela unificada e tratada
tabela_dataset_venda.to_excel('C:/Users/jeffe/Downloads/tabela_datasettestandobairros.xlsx')

# %% [markdown]
# # Inserção dos datasets e tratamentos de dados da IA de aluguel

# %%
tabela_aluga_juqueira = pd.read_excel("C:/Users/jeffe/Downloads/datasetJuqueiraAluga.xlsx") 
tabela_aluga_ato = pd.read_excel("C:/Users/jeffe/Downloads/Dataset_Aluga_Ato.xlsx") 
display(tabela_aluga_juqueira)
display(tabela_aluga_ato)
# Out:
#      Unnamed: 0            Imobiliaria        Cidade Estado  \
# 0             0  Imobiliária Junqueira   Piracicaba      SP
# 1             1  Imobiliária Junqueira   Piracicaba      SP
# 2             2  Imobiliária Junqueira   Piracicaba      SP
# 3             3  Imobiliária Junqueira   Piracicaba      SP
# 4             4  Imobiliária Junqueira   Piracicaba      SP
# ..          ...                    ...           ...    ...
# 681         681  Imobiliária Junqueira   Piracicaba      SP
# 682         682  Imobiliária Junqueira   Piracicaba      SP
# 683         683  Imobiliária Junqueira   Piracicaba      SP
# 684         684  Imobiliária Junqueira   Piracicaba      SP
# 685         685  Imobiliária Junqueira   Piracicaba      SP
#
#                    Bairro     Valor  Lançamento Venda/Aluguel  \
# 0        Vila Industrial   200000.0         NaN       Aluguel
# 1     Vila Independência   100000.0         NaN       Aluguel
# ...

# %%
#Unifica as tabelas de vendas e alugueis da imobiliaria Juqueira
tabela_venda = pd.concat([tabela_aluga_juqueira, tabela_aluga_ato], ignore_index=True) 

#mostra a tabela completa da imobiliaria Juqueira
display(tabela_venda)
# Out:
#       Unnamed: 0            Imobiliaria        Cidade Estado  \
# 0              0  Imobiliária Junqueira   Piracicaba      SP
# 1              1  Imobiliária Junqueira   Piracicaba      SP
# 2              2  Imobiliária Junqueira   Piracicaba      SP
# 3              3  Imobiliária Junqueira   Piracicaba      SP
# 4              4  Imobiliária Junqueira   Piracicaba      SP
# ...          ...                    ...           ...    ...
# 1069         383        Imobiliária Ato    PIRACICABA     SP
# 1070         384        Imobiliária Ato    PIRACICABA     SP
# 1071         385        Imobiliária Ato    PIRACICABA     SP
# 1072         386        Imobiliária Ato    PIRACICABA     SP
# 1073         387        Imobiliária Ato    PIRACICABA     SP
#
#                     Bairro     Valor Lançamento Venda/Aluguel  \
# 0         Vila Industrial   200000.0        NaN       Aluguel
# 1      Vila Independência   100000.0        NaN       Aluguel
# ...

# %%
#da um drop nas colunas: Unnamed: 0, Lançamentos, cidade e estado
tabela_venda = tabela_venda.drop(columns=['Unnamed: 0','Lançamento','Cidade','Estado', 'Imobiliaria', 'Unnamed: 0.1'])

# %%
tabela_venda['Bairro'] = tabela_venda['Bairro'].str.upper()
tabela_venda = tabela_venda.replace(' AGUA BRANCA ', ' ÁGUA BRANCA ').replace(' AGUA SECA ', ' ÁGUA SECA ').replace(' ASTURIAS ', ' ASTÚRIAS ').replace(' CHACARA ESPERIA ', ' CHáCARA ESPERIA ').replace(' CONCEICAO ', ' CONCEIçãO ').replace(' DOIS CORREGOS ', ' DOIS CóRREGOS ').replace(' GLEBAS CALIFORNIA ', ' GLEBAS CALIFóRNIA ').replace(' GRANDE PARQUE RESIDENCIAL ', ' GRAN PARk RESIDENCIAL ').replace(' HIGIENOPOLIS ', ' HIGIENóPOLIS ').replace(' JARAGUA ', ' JARAGUá ').replace(' JARDIM BARTIRA (TUPI) ', ' JARDIM BARTIRA ').replace(' JARDIM BRASILIA ', ' JARDIM BRASíLIA ').replace(' JARDIM CALIFORNIA ', ' JARDIM CALIFóRNIA ').replace(' MARIO DEDINI ', ' MáRIO DEDINI ').replace(' MONTE LIBANO ', ' MONTE LíBANO ').replace(' NOSSA SENHORA DE FATIMA ', ' NOSSA SENHORA DE FáTIMA ').replace(' NOVA AMERICA ', ' NOVA AMéRICA ').replace(' NOVO HORIZINTE ', ' NOVO HORIZoNTE ').replace(' PARQUE CHAPADAO ', ' PARQUE CHAPADãO ').replace(' PARQUE RESIDENCIAL PIRACICABA BALBO ', ' PARQUE RESIDENCIAL PIRACICABA ')
tabela_venda = tabela_venda.replace(' PARQUE SAO MATHEUS ', ' PARQUE SãO MATHEUS ').replace(" PAU D`ALHINHO ", " Pau D'Alhinho ").replace(' PAULICEIA ', ' PAULICéIA ').replace(' POMPEIA ', ' POMPéIA ').replace(' POMPEVA ', ' POMbEVA ').replace(' PREZOTO ', ' PREZOTtO ').replace(' SAO DIMAS ', ' SÃO DIMAS ').replace(' SAO FRANCISCO ', ' SãO FRANCISCO ').replace(' SÃO FRANCISCO AVENCAS ', ' SÃO FRANCISCO ').replace(' SAO JORGE ', ' SãO JORGE ').replace(' SAO JUDAS ', ' SãO JUDAS ').replace(' SAO LUIZ ', ' SãO LUIZ ').replace(' TANQUINHO (GUAMIUM) ', ' TANQUINHO ').replace(' VILA INDEPENDENCIA ', ' VILA INDEPENDÊNCIA ').replace(' VILA SONIA ', ' VILA SôNIA ')
tabela_venda = tabela_venda.replace(' AREIAO ', ' AREIãO ').replace(' AREAO ', ' AREIãO ').replace(' JARDIM SANTA IGNÊS II ', ' SANTA INES ').replace(' INDUSTRIAL ', ' Vila Industrial ').replace(' BOA ESPERANÇA ', ' Jardim Boa Esperança ')

tabela_venda['Bairro'] = tabela_venda['Bairro'].str.upper()
#muda o nome dos bairros para numeros
for n in range(len(lista_bairros)):
    tabela_venda = tabela_venda.replace(lista_bairros[n].upper(), n + 1) 
    
#Muda a venda para 1 e aluguel para 2
tabela_venda = tabela_venda.replace('Aluguel', 3)

#arrumar oq se repete em cima
tabela_venda = tabela_venda.replace('Prédio', 'Prédio Comercial').replace('Sala', 'Sala Comercial').replace('Prédio Comercial ', 'Prédio Comercial').replace('Terreno ', 'Terreno').replace('Galpão ', 'Galpão').replace('Casa Comercial ', 'Casa Comercial').replace('Casa ', 'Casa').replace('Apartamento ', 'Apartamento').replace('Salão ', 'Salão').replace('Chácara ', 'Chácara').replace('Sala Comercial ', 'Sala Comercial').replace('Kitnet ', 'Kitnet')

#nova lista de casa/apartamento/terreno para numeros
lista_cs_ap_tr_nova_aluga = ['Casa',
                    'Apartamento',
                    'Terreno',
                    'Prédio Comercial',
                    'Galpão',
                    'Sítio / Fazenda ',
                    'Casa Comercial',
                    'Salão',
                    'Chácara',
                    'Sala Comercial',
                    'Edícula ',
                    'Kitnet',
                    'Área',
                    'Casa em Condomínio',
                    'Barracão']
#Muda a casa/apartamento/terreno para numeros
for i in range(len(lista_cs_ap_tr_nova_aluga)):
    tabela_venda = tabela_venda.replace(lista_cs_ap_tr_nova_aluga[i], i + 1)
    
tabela_venda = tabela_venda[tabela_venda['Casa/Apartamento/Terreno'] <= 2]    

#tirar todas as linhas de preço que estao vazias
tabela_venda = tabela_venda[tabela_venda['Valor'] > 1]

tabela_venda = tabela_venda[tabela_venda['Venda/Aluguel'] == 3]

#tirar todas as linhas que nao tem m²
tabela_venda = tabela_venda[tabela_venda['Metros²'] >= 10]

tabela_venda = tabela_venda.fillna(0)

# %%
display(tabela_venda)
print(tabela_venda.info())
# Out:
#       Bairro    Valor  Venda/Aluguel  Casa/Apartamento/Terreno  Quartos  \
# 15         3  20000.0              3                         1     15.0
# 16         3  20000.0              3                         1      1.0
# 22        25  15000.0              3                         1      4.0
# 26        35  15000.0              3                         1      5.0
# 32        17  12500.0              3                         2      4.0
# ...      ...      ...            ...                       ...      ...
# 1044       3   7005.0              3                         2      4.0
# 1047     214   8005.0              3                         1      0.0
# 1049       3   8505.0              3                         2      4.0
# 1053       3   9505.0              3                         2      4.0
# 1055      37  10005.0              3                         1      3.0
#
#       Suites  Vagas Estacionamento  Metros²
# 15       0.0                  20.0  1100.00
# ...

# %% [markdown]
# # Iniciando a IA de venda

# %%
#Correlaçao entre cada elemento que ha na tabela
display(tabela_dataset_venda.corr()[["Valor"]])
# Out:
#                              Valor
# Bairro                   -0.161126
# Valor                     1.000000
# Venda/Aluguel                  NaN
# Casa/Apartamento/Terreno -0.233242
# Quartos                   0.002321
# Suites                    0.204195
# Vagas Estacionamento      0.132067
# Metros²                   0.485476

# %%
#criar grafico
sns.heatmap(tabela_dataset_venda.corr()[["Valor"]], cmap = 'Blues', annot = True)

#exibir grafico
plt.show()

# %%
#preparação
#separar os dados em X e Y

#Separa os valores que serão predizidos para a IA
y_venda = tabela_dataset_venda["Valor"]

#Separa os outros valores que a IA levara em conta para realizar a predição
x_venda = tabela_dataset_venda.drop('Valor', axis = 1)

#Função propria que randomiza os dados entre os treinos e os testes
x_train_venda, x_test_venda, y_train_venda, y_test_venda = train_test_split(x_venda, y_venda)

# %%
#criação e treino da ia
#criação da IA

#Cria um modelo de regressão linear
model_linearRegression_venda = LinearRegression()

#Cria um modelo de arvore de decissão
model_randomForestRegressor_venda = RandomForestRegressor()

#treinar a IA

#Treina o modelo de regressão linear
model_linearRegression_venda.fit(x_train_venda, y_train_venda)

#Treina o modelo de arvore de decissão
model_randomForestRegressor_venda.fit(x_train_venda, y_train_venda)
# Out:
# RandomForestRegressor()

# %%
#realiza um teste para ver quão eficaz é a IA com os dados que separamos para teste
prevision_linearRegression_venda = model_linearRegression_venda.predict(x_test_venda)
prevision_randomForestRegresson_venda = model_randomForestRegressor_venda.predict(x_test_venda)

#printa a porcentagem que cada modelo esta se saindo, quanto mais perto de 1 melhor
print(r2_score(y_test_venda, prevision_linearRegression_venda))
print(r2_score(y_test_venda, prevision_randomForestRegresson_venda))
# Out:
# 0.3140124924376039
# 0.9433631624851996

# %% [markdown]
# # Iniciando a IA de aluguel

# %%
#Correlaçao entre cada elemento que ha na tabela
display(tabela_venda.corr()[["Valor"]])
# Out:
#                              Valor
# Bairro                   -0.184543
# Valor                     1.000000
# Venda/Aluguel                  NaN
# Casa/Apartamento/Terreno -0.101599
# Quartos                   0.571555
# Suites                    0.439469
# Vagas Estacionamento      0.688902
# Metros²                   0.653009

# %%
#criar grafico
sns.heatmap(tabela_dataset_venda.corr()[["Valor"]], cmap = 'Blues', annot = True)

#exibir grafico
plt.show()

# %%
#preparação
#separar os dados em X e Y

#Separa os valores que serão predizidos para a IA
y_aluga = tabela_venda["Valor"]

#Separa os outros valores que a IA levara em conta para realizar a predição
x_aluga = tabela_venda.drop('Valor', axis = 1)

#Função propria que randomiza os dados entre os treinos e os testes
x_train_aluga, x_test_aluga, y_train_aluga, y_test_aluga = train_test_split(x_aluga, y_aluga)

# %%
#criação e treino da ia
#criação da IA

#Cria um modelo de regressão linear
model_linearRegression_aluga = LinearRegression()

#Cria um modelo de arvore de decissão
model_randomForestRegressor_aluga = RandomForestRegressor()

#treinar a IA

#Treina o modelo de regressão linear
model_linearRegression_aluga.fit(x_train_aluga, y_train_aluga)

#Treina o modelo de arvore de decissão
model_randomForestRegressor_aluga.fit(x_train_aluga, y_train_aluga)
# Out:
# RandomForestRegressor()

# %%
#realiza um teste para ver quão eficaz é a IA com os dados que separamos para teste
prevision_linearRegression_aluga = model_linearRegression_aluga.predict(x_test_aluga)
prevision_randomForestRegresson_aluga = model_randomForestRegressor_aluga.predict(x_test_aluga)

#printa a porcentagem que cada modelo esta se saindo, quanto mais perto de 1 melhor
print(r2_score(y_test_aluga, prevision_linearRegression_aluga))
print(r2_score(y_test_aluga, prevision_randomForestRegresson_aluga))
# Out:
# 0.5549884250605515
# 0.5950316456122033

# %% [markdown]
# # Tratamento dos dados de entrada

# %%
#Adiciona uma nova tabela que sera utilizada para predizer os dados inseridos
tabela_previsao = pd.read_excel("C:/Users/jeffe/Downloads/tabela_previsao.xlsx") 
display(tabela_previsao)
# Out:
# Empty DataFrame
# Columns: [Bairro, Venda/Aluguel, Casa/Apartamento/Terreno, Quartos, Suites, Vagas Estacionamento, Metros²]
# Index: []

# %%
#Função para tratar os dados de entrada, adicionando-os para nova tabela e prevendo-os.
def previsao_imobiliaria():
    VagaEstacionamento = vagas.get()
    vendaAluga = venda_aluga.get()
    CsApTr = cs_ap_tr.get()
    Bairro = bairro.get()
    Quarto = quartos.get()
    Suite = suites.get()
    M2s = m2.get()
    
    #filtro para quando desejar comprar
    if vendaAluga == 'Comprar':
        VendaAluga = 1
        
        #Filtro para terreno
        if CsApTr == 'Terreno':
            Cs_Ap_Tr = 1
            BairroNum = 0
            for n in range(len(nova_lista_bairros)):
                if Bairro == nova_lista_bairros[n]:
                    BairroNum = n + 1
                else:
                    valorFinal.set('Bairro não encontrado')
            
            #Filtro para metragem do ambiente
            if M2s <= 10:
                valorFinal.set('Valor de metragem não compativel')
            VagaEstacionamento = 0
            Quarto = 0
            Suite = 0
            tabela_previsao.loc[0] = [BairroNum, VendaAluga, Cs_Ap_Tr, Quarto, Suite, VagaEstacionamento, M2s]
            
        #Filtro para casa    
        if CsApTr == 'Casa':
            Cs_Ap_Tr = 2
            BairroNum = 0
            for n in range(len(nova_lista_bairros)):
                if Bairro == nova_lista_bairros[n]:
                    BairroNum = n + 1
                else:
                    valorFinal.set('Bairro não encontrado')
            if M2s <= 10:
                valorFinal.set('Valor de metragem não compativel')
            tabela_previsao.loc[0] = [BairroNum, VendaAluga, Cs_Ap_Tr, Quarto, Suite, VagaEstacionamento, M2s]
            
        #Filtro para apartamento    
        if CsApTr == 'Apartamento':
            Cs_Ap_Tr = 3
            BairroNum = 0
            for n in range(len(nova_lista_bairros)):
                if Bairro == nova_lista_bairros[n]:
                    BairroNum = n + 1
                else:
                    valorFinal.set('Bairro não encontrado')
            if M2s <= 10:
                valorFinal.set('Valor de metragem não compativel')
            tabela_previsao.loc[0] = [BairroNum, VendaAluga, Cs_Ap_Tr, Quarto, Suite, VagaEstacionamento, M2s]
            
        #Realiza a previsão com o modelo treinado
        previsao_venda = model_randomForestRegressor_venda.predict(tabela_previsao)
        msg_final_venda = f'A previsao do valor de {vendaAluga} da(o) {CsApTr}\nfoi de: R$ {locale.format_string("%.2f", previsao_venda[0],)}'
        valorFinal.set(msg_final_venda)
      
    #Filtro para quando desejar alugar
    if vendaAluga == 'Alugar':
        VendaAluga = 3
        
        #Filtro para terreno
        if CsApTr == 'Terreno':
            Cs_Ap_Tr = 3
            for n in range(len(nova_lista_bairros)):
                if Bairro == nova_lista_bairros[n]:
                    BairroNum = n + 1
                else:
                    valorFinal.set('Bairro não encontrado')
            
            #Filtro para metragem do ambiente
            if M2s <= 10:
                valorFinal.set('Valor de metragem não compativel')
            VagaEstacionamento = 0
            Quarto = 0
            Suite = 0
            tabela_previsao.loc[0] = [BairroNum, VendaAluga, Cs_Ap_Tr, Quarto, Suite, VagaEstacionamento, M2s]
            valorFinal.set('Não alugamos terrenos')
            
        #Filtro para casa    
        if CsApTr == 'Casa':
            Cs_Ap_Tr = 1
            BairroNum = 0
            for n in range(len(nova_lista_bairros)):
                if Bairro == nova_lista_bairros[n]:
                    BairroNum = n + 1
                else:
                    valorFinal.set('Bairro não encontrado')
            if M2s <= 10:
                valorFinal.set('Valor de metragem não compativel')
            tabela_previsao.loc[0] = [BairroNum, VendaAluga, Cs_Ap_Tr, Quarto, Suite, VagaEstacionamento, M2s]
        
        #Filtro para apartamento
        if CsApTr == 'Apartamento':
            Cs_Ap_Tr = 2
            BairroNum = 0
            for n in range(len(nova_lista_bairros)):
                if Bairro == nova_lista_bairros[n]:
                    BairroNum = n + 1
                else:
                    valorFinal.set('Bairro não encontrado')
            if M2s <= 10:
                valorFinal.set('Valor de metragem não compativel')
            tabela_previsao.loc[0] = [BairroNum, VendaAluga, Cs_Ap_Tr, Quarto, Suite, VagaEstacionamento, M2s]
        previsao_aluga = model_randomForestRegressor_aluga.predict(tabela_previsao)
        msg_final_venda = f'A previsao do valor de {vendaAluga} da(o) {CsApTr}\nfoi de: R$ {locale.format_string("%.2f", previsao_venda[0],)}'
        valorFinal.set(msg_final_aluga)

# %% [markdown]
# # Criamento do front do programa

# %%
#Inicia o modo janela do tkinter
janela = Tk()

#Define o tamanha da janela que sera criada com o tkinter
janela.geometry("480x1080")

#Altera a cor de fundo
janela['background'] = '#292354'

# %%
#Define o titulo da janela
janela.title('previsões imobiliarias')
# Out:
# ''

# %%
titulo_janela = Label(janela, text = 'Preveja o Seu Imóvel', font = ('Roboto', 18), foreground="white", background="#292354").grid(column=0, row=0, padx=10, pady=10, columnspan=1)

# %%
tipo_imovel = Label(janela, text = 'Tipo Imovél: ', font = ('Roboto', 14), foreground="white", background="#292354").grid(column=0, row=1, padx=20, pady=20, columnspan=1, sticky=W)

# %%
tipo_pretensao = Label(janela, text = 'Pretensão: ', font = ('Roboto', 14), foreground="white", background="#292354").grid(column=0, row=3, padx=20, pady=20, columnspan=1, sticky=W)

# %%
tipo_localizacao = Label(janela, text = 'Localização: ', font = ('Roboto', 14), foreground="white", background="#292354").grid(column=0, row=5, padx=20, pady=20, columnspan=1, sticky=W)

# %%
#Inicia a string venda_aluga para receber os valores do combobox
venda_aluga = StringVar()

#Inicia o combobox
combobox_venda_aluga = ttk.Combobox(janela, width = 27, textvariable = venda_aluga,  font = ('Roboto', 12), height=10, background="#292354")

#Valores que serão apresentados no bombobox
combobox_venda_aluga['values'] = ('Comprar', 'Alugar')

#Formata o combobox
combobox_venda_aluga.grid(column=0, row=4, padx=15, sticky='nswe', columnspan=1)

# %%
#Inicia a string cs_ap_tr para receber os valores do combobox
cs_ap_tr = StringVar()

#Inicia o combobox
combobox_cs_ap_tr = ttk.Combobox(janela, width = 27, textvariable = cs_ap_tr,  font = ('Roboto', 12), height=10)

#Valores que serão apresentados no bombobox
combobox_cs_ap_tr['values'] = ('Casa', 'Apartamento', 'Terreno')

#Formata o combobox
combobox_cs_ap_tr.grid(column=0, row=2, padx=15, sticky='nswe', columnspan=1)

# %%
#Inicia a string bairro para receber os valores do combobox
bairro = StringVar()

#Realiza um for para transformar todos os bairros da lista_bairros em letras maiusculas
nova_lista_bairros = [x.upper() for x in lista_bairros]

#Inicia o combobox
combobox_bairro = ttk.Combobox(janela, width = 27, textvariable = bairro,  font = ('Roboto', 11), height=10)

#Valores que serão apresentados no bombobox em ordem alfabetica
combobox_bairro['values'] = sorted(nova_lista_bairros)

#Formata o combobox
combobox_bairro.grid(column=0, row=6, padx=15, sticky='nswe', columnspan=1)

# %%
#Inicia o int quartos para receber os valores do Entry
quartos = IntVar()

#Texto apresentado na janela ja formatado
texto_quartos = Label(janela, text = 'Quantidade de Quarto(s): ', font = ('Roboto', 14), foreground="white", background="#292354").grid(column=0, row=7, padx=20, pady=20, columnspan=1, sticky=W)

#caixa de texto para receber o valor do cliente
quant_quartos = Entry(janela, textvariable = quartos,  font = ('Roboto', 12)).grid(column=0, row=8, padx=15, sticky='nswe', columnspan=1)

# %%
#Inicia o int suites para receber os valores do Entry
suites = IntVar()

#Texto apresentado na janela ja formatado
texto_suites = Label(janela, text = 'Quantidade de Suíte(s): ', font = ('Roboto', 14), foreground="white", background="#292354").grid(column=0, row=9, padx=20, pady=20, columnspan=1, sticky=W)

#caixa de texto para receber o valor do cliente
quant_suites = Entry(janela, textvariable = suites,  font = ('Roboto', 12)).grid(column=0, row=10, padx=15, sticky='nswe', columnspan=1)

# %%
#Inicia o int vagas para receber os valores do combobox
vagas = IntVar()

#Texto apresentado na janela ja formatado
texto_vagas = Label(janela, text = 'Quantidade de vaga(s): ', font = ('Roboto', 14), foreground="white", background="#292354").grid(column=0, row=11, padx=20, pady=20, columnspan=1, sticky=W)

#caixa de texto para receber o valor do cliente
quant_vagas = Entry(janela, textvariable = vagas,  font = ('Roboto', 12)).grid(column=0, row=12, padx=15, sticky='nswe', columnspan=1)

# %%
#Inicia o int m2 para receber os valores do combobox
m2 = DoubleVar()

#Texto apresentado na janela ja formatado
texto_m2 = Label(janela, text = 'Metros Quadrados: ', font = ('Roboto', 14), foreground="white", background="#292354").grid(column=0, row=13, padx=20, pady=20, columnspan=1, sticky=W)

#caixa de texto para receber o valor do cliente
quant_m2 = Entry(janela, textvariable = m2,  font = ('Roboto', 12)).grid(column=0, row=14, padx=15, sticky='nswe', columnspan=2)

# %%
#Cria um botão com o camando de iniciar a função previsao_imobiliaria
botao = Button(janela, text = 'Enviar', command = previsao_imobiliaria, font = ('Roboto', 14), foreground="black", background="#FFDE59").grid(column=0, row=15, padx=20, pady=20, columnspan=1)

# %%
#Inicia a string valorFinal para receber e mostrar os valores
valorFinal = StringVar()

#Texto apresentado no fim da janela enquanto os valores sâo digitados
valorFinal.set('Complete as caixas para predizer o valor a pagar')

#Texto no fim da janela que mudara conforme for o andamento do projeto
texto_final = Label(janela, textvariable = valorFinal, font = ('Roboto', 14), foreground="white", background="#292354").grid(column=0, row=16, padx=20, columnspan=1)

# %%
#deixa a janela do tkinter aberta por todo tempo
janela.mainloop()
